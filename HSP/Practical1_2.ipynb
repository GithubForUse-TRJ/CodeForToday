# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/MyDrive/Datasets
# %ls
# df=pd.read_csv('cwurData.csv')
# Out:
# Mounted at /gdrive
# /gdrive/MyDrive/Datasets
#  Admission_Predict.csv
#  Admission_Predict_Ver1.1.csv
# 'Breast Cancer Wisconsin Dataset.csv'
#  cwurData.csv
#  data.csv
#  dataset_31_credit-g.csv
# 'default of credit card clients (1).xlsx'
# 'FIFA 19 Dataset.csv'

# %%
df=pd.read_csv('cwurData.csv')

# %%
df.head(3)
# Out:
#    world_rank                            institution  ...   score  year
# 0           1                     Harvard University  ...  100.00  2012
# 1           2  Massachusetts Institute of Technology  ...   91.67  2012
# 2           3                    Stanford University  ...   89.50  2012
#
# [3 rows x 14 columns]

# %%
plt.figure(figsize=(40,10))
plt.hist(df['institution'])
plt.xticks(rotation=90)
plt.show()

# %%
bins_l=[40,50,60,70,80, 83,90,100]
plt.figure(figsize=(20,10))
plt.hist(df['score'],bins=bins_l)
plt.xticks(rotation=90)
plt.show()

# %%
# sns.histplot(df['country'],kde=True,color='green')
sns.histplot(df['alumni_employment'],kde=True,color='green')

# %%
plt.figure(figsize=(2,7))
plt.boxplot(df['score'])
plt.show()

# %%
plt.figure(figsize=(15,20))
plt.scatter(df['country'],df['institution'],color="red")
