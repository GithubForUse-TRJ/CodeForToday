# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/MyDrive/Datasets
# %ls
# df=pd.read_csv('cwurData.csv')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-f2c8ab40c59f> in <module>()
#       2 import matplotlib.pyplot as plt
#       3 from google.colab import drive
# ----> 4 drive.mount('/gdrive')
#       5 get_ipython().magic('cd /gdrive/MyDrive/Datasets')
#       6 get_ipython().magic('ls')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, use_metadata_server)
#     113       force_remount=force_remount,
#     114       timeout_ms=timeout_ms,
# --> 115       ephemeral=True)
#     116
#     117
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, use_metadata_server, ephemeral)
#     133   if ephemeral:
#     134     _message.blocking_request(
# --> 135         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None)
#     136
# ...

# %%
# %ls

# %%
# df=pd.read_excel('DS1.xlsx')
df=pd.read_csv('cwurData.csv')

# %%
df

# %%
# df1=df.drop([1,2],inplace=False)
df1=df.drop([2,4],inplace=False)

# %%
df1.head()

# %%
df2=df.fillna(df.mean(), inplace=False, axis=0)
# df3=df.fillna(df.median(), inplace=False)
# df4=df.fillna(df.mode(),inplace=False,axis=0)
df2
# df3
# df4

# %%
df2=df.corr()
df2

# %%
df4=df.fillna(df.mode(),inplace=False,axis=0)
df4[195:205]
